# %% [markdown]
# scraping data ulasan aplikasi google play store

# %%
#Referensi: https://www.linkedin.com/pulse/how-scrape-google-play-reviews-4-simple-steps-using-python-kundi/
#download library google-play-scraper
# !pip install google-play-scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: google-play-scraper in /usr/local/lib/python3.8/dist-packages (1.2.2)

# %% [markdown]
# Impor paket yang diperlukan

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
#scrape jumlah ulasan yang diinginkan
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.shopee.id',
    lang='id',  #disini kita mau men scrape data ulasan aplikasi shopee yang berada di google play store
    country='id', #kita setting bahasa nya menjadi bahasa indonesia
    sort=Sort.MOST_RELEVANT, # # kemudian kita gunakan most_relevan untuk mendapatkan ulasan yang paling relevant
    count=100, # disini jumlah ulasan yang mau kita ambil ada seribu
    filter_score_with=None # # kemudian di filter_score kita gunakan None untuk mengambil semua score atau ratting bintang 1 sampai 5
)

# %%
df_busu = pd.DataFrame(np.array(result),columns=['review'])

df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))

df_busu.head()
# Out:
#                                reviewId                        userName  \
# 0  12fcf2b1-9710-455d-b35c-6575c96e75d0        Syarifah Fatimah Azzahra
# 1  913e34f7-9df0-4268-bd3e-3aeae5cec92c                        Rian Sub
# 2  e80c834c-5893-4701-93bd-5da597830dd7                        Arief QL
# 3  09ed3cab-fb6e-4f54-a876-7677daef2470              achmad wafiq pasya
# 4  7b95beb8-3e31-4f68-9e5c-352c2885896f  Nabila Zalfaa Rihhadatul 'Aisy
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a-/AD5-W...
# 1  https://play-lh.googleusercontent.com/a/AEdFTp...
# 2  https://play-lh.googleusercontent.com/a-/AD5-W...
# 3  https://play-lh.googleusercontent.com/a/AEdFTp...
# 4  https://play-lh.googleusercontent.com/a-/AD5-W...
#
#                                              content  score  thumbsUpCount  \
# 0  Terlalu banyak fitur tak penting. Harusnya fok...      1            256
# 1  Aplikasi Super Lemot, Sering eror. 1. Aplikasi...      2           2887
# 2  Overall OK. Tapi butuh bandwidth besar. Sering...      1            650
# 3  Update bukannya tambah bagus malah tambah ngeb...      1           2632
# 4  Shopee ini kebanyakan fitur yang menurut aku k...      2             34
#
#   reviewCreatedVersion                  at  \
# 0              2.96.24 2023-01-26 18:38:21
# 1              2.96.24 2023-01-17 10:10:25
# 2              2.96.24 2023-01-22 13:49:11
# 3              2.96.24 2023-01-15 11:44:53
# 4              2.95.52 2023-01-24 11:17:38
#
#                                         replyContent           repliedAt
# 0  Hi kak maaf ya terkait kendala aplikasi yg nge... 2023-01-27 00:05:19
# 1  Hi kak, maaf ya udh buat km ga nyaman🙏 terkait... 2023-01-13 07:00:58
# 2  Hi kak, mohon maaf atas kendala yg dialami. Sh... 2023-01-22 14:14:21
# 3  Hi kk achmad, maaf ya udah buat ganyaman. Saat... 2023-01-15 12:15:10
# 4  Hi kak, maaf atas ketidaknyamanannya, terkait ... 2023-01-24 12:12:15

# %%
len(df_busu.index) #kemudian hitung kembali berapa jumlah data yg didapatkan
# Out:
# 100

# %%
df_busu[['userName', 'score','at', 'content']].head()  #preview userName, rating, date-time, and reviews only
# Out:
#                          userName  score                  at  \
# 0        Syarifah Fatimah Azzahra      1 2023-01-26 18:38:21
# 1                        Rian Sub      2 2023-01-17 10:10:25
# 2                        Arief QL      1 2023-01-22 13:49:11
# 3              achmad wafiq pasya      1 2023-01-15 11:44:53
# 4  Nabila Zalfaa Rihhadatul 'Aisy      2 2023-01-24 11:17:38
#
#                                              content
# 0  Terlalu banyak fitur tak penting. Harusnya fok...
# 1  Aplikasi Super Lemot, Sering eror. 1. Aplikasi...
# 2  Overall OK. Tapi butuh bandwidth besar. Sering...
# 3  Update bukannya tambah bagus malah tambah ngeb...
# 4  Shopee ini kebanyakan fitur yang menurut aku k...

# %%
#Run This Code to Sort the Data By Date 

new_df = df_busu[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#                     userName  score                  at  \
# 0   Syarifah Fatimah Azzahra      1 2023-01-26 18:38:21
# 68           Razman RasMania      3 2023-01-26 14:05:27
# 37                Jhon Manik      1 2023-01-26 11:40:42
# 95             pecinta damai      2 2023-01-26 05:07:05
# 76         Muhammad Amaludin      1 2023-01-25 21:43:35
#
#                                               content
# 0   Terlalu banyak fitur tak penting. Harusnya fok...
# 68  Cek sinyal stabil, spek hp cukuplah ram 4gb si...
# 37  Peraturan aneh Shopee, skrg pemilihan kurir ha...
# 95  Lemot bener... Jaringan internet sudah kenceng...
# 76  HP saya ram 4GB speed wifi saya 300-2mb/s rata...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']] #get userName, rating, date-time, and reviews only

# %%
my_df.head()
# Out:
#                     userName  score                  at  \
# 0   Syarifah Fatimah Azzahra      1 2023-01-26 18:38:21
# 68           Razman RasMania      3 2023-01-26 14:05:27
# 37                Jhon Manik      1 2023-01-26 11:40:42
# 95             pecinta damai      2 2023-01-26 05:07:05
# 76         Muhammad Amaludin      1 2023-01-25 21:43:35
#
#                                               content
# 0   Terlalu banyak fitur tak penting. Harusnya fok...
# 68  Cek sinyal stabil, spek hp cukuplah ram 4gb si...
# 37  Peraturan aneh Shopee, skrg pemilihan kurir ha...
# 95  Lemot bener... Jaringan internet sudah kenceng...
# 76  HP saya ram 4GB speed wifi saya 300-2mb/s rata...

# %%
new_df.to_csv("scrapped_data.csv", index = False)  #kemudian save menjadi file csv
